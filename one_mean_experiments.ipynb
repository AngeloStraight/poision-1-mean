# %%
from one_mean_experiment import OneMeanExperiment
import numpy as np
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
random_experiment = OneMeanExperiment(p1=(0,0), p2=(1,1), random=True, low=0.0, high=0.5, size=(1500,2))

# %%
random_experiment.show_plot()

# %%
random_experiment.run_analysis()

# %%
random_experiment.show_new_mean_plot()

# %%
random_experiment.show_analysis("Random Experiment")

# %%
random_experiment.get_proportion()
# Out:
# Size of Dataset: 1500
# Size of Poison Set: 37280.0
# 0.040236051502145924

# %%
from sklearn import datasets

# %%
iris = datasets.load_iris()
X = iris.data[:, :2]  # we only take the first two features.

# %%
iris_experiment = OneMeanExperiment(X)

# %%
iris_experiment.show_plot()

# %%
iris_experiment.run_analysis()

# %%
iris_experiment.show_new_mean_plot()

# %%
iris_experiment.show_analysis("Iris Dataset")

# %%
iris_experiment.get_proportion()
# Out:
# Size of Dataset: 150
# Size of Poison Set: 11520.0
# 0.013020833333333334

# %%
diabetes = datasets.load_diabetes()
X2 = diabetes.data[:, [0, 2]] # diabetes data split on age and bmi

# %%
diabetes_experiment = OneMeanExperiment(X2)

# %%
diabetes_experiment.show_plot()

# %%
diabetes_experiment.run_analysis()

# %%
diabetes_experiment.show_new_mean_plot()

# %%
diabetes_experiment.show_analysis("Diabetes Dataset")

# %%
diabetes_experiment.get_proportion()
# Out:
# Size of Dataset: 442
# Size of Poison Set: 18730.0
# 0.02359850507207688
